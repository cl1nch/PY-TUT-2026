# %% [markdown]
# <a href="https://colab.research.google.com/github/cl1nch/PY-TUT-2026/blob/main/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OWL-ML/IBFW-PY-2026-Tutorial/blob/main/functions.ipynb)
#
# *(Tip: Ctrl/Cmd + click to open in a new tab)*

# %% [markdown]
# # Funktionen / *Functions*
# Python-Funktionen sind ein Block von Anweisungen, der eine bestimmte Aufgabe ausführt. Die Idee besteht darin, häufig oder wiederholt durchgeführte Aufgaben zusammenzufassen und eine Funktion zu erstellen, sodass wir anstelle des wiederholten Schreibens desselben Codes für unterschiedliche Eingaben die Funktion aufrufen können, um den darin enthaltenen Code immer wieder zu verwenden.
# Die folgenden Schritte beschreiben, wie man eine Funktion definiert:
#
# - Wir verwenden das Schlüsselwort def, um die Funktion zu deklarieren, gefolgt vom Funktionsnamen.
# - Wir fügen Parameter zur Funktion hinzu: sie sollten innerhalb der Klammern der Funktion stehen. Die Zeile wird mit einem Doppelpunkt beendet.
# - Die erste Anweisung einer Funktion kann optional sein: die Dokumentationszeichenkette (docstring) der Funktion.
# - Wir fügen die Anweisungen hinzu, die die Funktion ausführen soll.
# - Wir beenden die Funktion mit einer return-Anweisung, wenn die Funktion etwas ausgeben soll. Ohne die return-Anweisung gibt die Funktion None zurück.
#
# ---
#
# *Python Functions are a block of statements that does a specific task. The idea is to put some commonly or repeatedly done task together and make a function so that instead of writing the same code again and again for different inputs, we can do the function calls to reuse code contained in it over and over again.*
#
# *The following are the steps to define a function:*
# - *Use the keyword def to declare the function and follow this up with the function name.*
# - *Add parameters to the function: they should be within the parentheses of the function. End your line with a colon.*
# - *The first statement of a function can be an optional statement; the documentation string of the function or docstring.*
# - *Add statements that the functions should execute.*
# - *End your function with a return statement if the function should output something. Without the return statement, your function will return `None`.*
#
# Syntax:
# ```
# def function_name(parameters):
#     """Docstring"""
#     # body of the function
#     # optional return statement
#     return expression
# ```

# %%
# a function may not have parameters
# can be as simple as printing a statement
def fun():
    print("Welcome to fun with python")

# %%
fun() # Driver code to call a function
# Out:
# Welcome to fun with python

# %%
def evenOdd(x):
    if (x % 2 == 0):
        return "Even"
    else:
        return "Odd"

print(evenOdd(16))
print(evenOdd(7))

result = evenOdd(76)
print(result)
# Out:
# Even
# Odd
# Even

# %% [markdown]
# ### Aufgabe 1 / *Exercise 1*
# Schreibe eine Funktion, die als Input einen Namen erhält und einen Gruß ausgibt.
#
# ---
#
# Write a function that takes user name input and prints a greeting.
# ```
# greet("Tom")
#
# Hello, Tom!
# ```

# %%
def greeting(name):
  print(f'Greetings {name} --.-..-.-.')

greeting("ttttt")
# Out:
# Greetings ttttt --.-..-.-.

# %% [markdown]
# # Docstring
#
# Docstrings beschreiben, was eine Funktion macht, zum Beispiel den erwarteten Datentyp der Eingaben, die durchgeführten Berechnungen oder die Rückgabewerte. Diese Beschreibungen dienen als Dokumentation der Funktion, sodass jede Person, die den Docstring der Funktion liest, versteht, was die Funktion macht, ohne den gesamten Code in der Funktionsdefinition nachverfolgen zu müssen.
#
# Funktions-Docstrings werden direkt in der Zeile nach dem Funktionskopf eingefügt und stehen zwischen dreifachen Anführungszeichen.
#
# Um den Docstring einer Funktion in Python zu überprüfen, kann die eingebaute Funktion `help()` verwenden werden oder auf das Attribut `__doc__` der Funktion zugegriffen werden.
#
# ---
#
# *Docstrings describe what your function does, such as the data type of the input it expects, computations it performs or its return values. These descriptions serve as documentation for your function so that anyone who reads your function’s docstring understands what your function does, without having to trace through all the code in the function definition.*
#
# *Function docstrings are placed in the immediate line after the function header and are placed in between triple quotation marks.*
#
# *To check the docstring of a function in Python, you can use the built-in `help()` function or access the function’s `__doc__` attribute.*

# %%
def evenOdd(x):
    """
    This function calculates if a number is even or odd.
    input:
        x: int
    output:
        "Even" or "Odd": str
    """
    if (x % 2 == 0):
        return "Even"
    else:
        return "Odd"

# %%
help(evenOdd)

# %%
print(evenOdd.__doc__)

# %%
# remember we used 'len' to get the length of a list, string etc.
help(len)

# %%
print(len.__doc__)

# %% [markdown]
# # Parameter und Argumente / *Parameters and Arguments*
#
# Beim Definieren einer Funktion wird innerhalb der Klammern eine Liste von Variablen angegeben, die als formale Parameter bezeichnet werden. Diese Parameter fungieren als Platzhalter für die Daten oder Argumente, die der Funktion beim Aufruf übergeben werden. Beim Aufrufen der Funktion muss jedem formalen Parameter ein Wert zugewiesen werden.
#
# Je nachdem, wie die Argumente beim Definieren einer Python-Funktion angegeben werden, werden sie in die folgenden Kategorien eingeteilt:
# * Positions- oder Pflichtargumente
# * Schlüsselwortargumente
# * Standardargumente
# * Beliebige oder variabel lange Argumente
#
# ---
#
# *While defining a function, you specify a list of variables (known as formal parameters) within the parentheses. These parameters act as placeholders for the data or arguments that will be passed to the function when it is called. When the function is called, value to each of the formal parameters must be provided.*
#
# *Based on how the arguments are declared while defining a Python function, they are classified into the following categories:*
# - *Positional or Required Arguments*
# - *Keyword Arguments*
# - *Default Arguments*
# - *Arbitrary or Variable-length Arguments*

# %% [markdown]
# Bei **Positionsargumenten** werden die Werte den Parametern entsprechend ihrer Reihenfolge im Funktionsaufruf zugewiesen.
#
# ---
#
# In **positional arguments**, values are assigned to parameters based on their order in the function call.

# %%
def calculateProfit(item_name, cost, price):
    """
    calculates profit of an item.
    input:
        item_name: str
        cost: float|int
        price: float|int
    """
    profit = price - cost
    print(f'By selling {item_name}, you made a profit of {profit:.2f} euros.')

# %%
# correct call
calculateProfit("pencil sharpner", 8.27, 10)
# Out:
# By selling pencil sharpner, you made a profit of 1.73 euros.

# %%
# will lead to error
calculateProfit(10, "pen", 7.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9045/3943657407.py in <cell line: 0>()
#       1 # will lead to error
# ----> 2 calculateProfit(10, "pen", 7.3)
#
# /tmp/ipykernel_9045/1772264720.py in calculateProfit(item_name, cost, price)
#       7         price: float|int
#       8     """
# ----> 9     profit = price - cost
#      10     print(f'By selling {item_name}, you made a profit of {profit:.2f} euros.')
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'

# %%
# this will also lead to error
calculateProfit("pen", 7.3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9045/1202677140.py in <cell line: 0>()
#       1 # this will also lead to error
# ----> 2 calculateProfit("pen", 7.3)
#
# TypeError: calculateProfit() missing 1 required positional argument: 'price'

# %% [markdown]
# ### Aufgabe 2 / Exercise 2
# Schreibe eine Funktion, die eine Liste von Zahlen und einen Multiplikator entgegennimmt und jede Zahl in der Liste mit dem angegebenen Multiplikator multipliziert.
#
# ---
#
# *Write a function that takes a list of numbers and a multiplier and multiplies every number in the list by the given multiplier.*

# %%
l1 = [14, 45, 11]

def listMultiplier(list, multiplier):
  result = []
  for x in list:
    result = x * multiplier
    print(result)

print(listMultiplier(l1, 4))
# Out:
# 56
# 180
# 44
# None

# %% [markdown]
# Bei **Schlüsselwortargumenten** werden die Werte durch explizite Angabe der Parameternamen übergeben, sodass die Reihenfolge keine Rolle spielt.
#
# ---
#
# *In **keyword arguments**, values are passed by explicitly specifying the parameter names, so the order doesn’t matter.*

# %%
calculateProfit(price=10, item_name="pen", cost=7.3)
# Out:
# By selling pen, you made a profit of 2.70 euros.

# %% [markdown]
# Wie würden wir die Funktion list_multiply unter Verwendung von Schlüsselwortargumenten aufrufen?
#
# ---
#
# *How would we call function `list_multiply` using keyword arguments?*

# %%
listMultiplier(list=[1,4,7,8], multiplier=10)
# Out:
# 10
# 40
# 70
# 80

# %% [markdown]
# Ein **Standardargument** ist ein Parameter, der einen voreingestellten Wert annimmt, wenn beim Funktionsaufruf kein Wert für dieses Argument übergeben wird.
#
# ---
#
# *A **default argument** is a parameter that assumes a default value if a value is not provided in the function call for that argument.*

# %%
def calculateProfit(item_name, price, cost=10):
    """
    calculates profit of an item.
    input:
        item_name: str
        price: float|int
        cost: float|int. default value 10
    """
    profit = price - cost
    print(f'By selling {item_name}, you made a profit of {profit:.2f} euros.')

# %% [markdown]
# Standardargumente sollten jedoch nach den Parametern ohne voreingestellten Wert definiert werden.
#
# ---
#
# *However, default arguments should be defined after the parameters without any default value.*

# %%
def calculateProfit(item_name, cost=10,  price):
    """
    calculates profit of an item.
    input:
        item_name: str
        price: float|int
        cost: float|int. default value 10
    """
    profit = price - cost
    print(f'By selling {item_name}, you made a profit of {profit:.2f} euros.')
# Out:
#   File "/tmp/ipykernel_9045/3116159305.py", line 1
#     def calculateProfit(item_name, cost=10,  price):
#                                              ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
calculateProfit(price=10, item_name="pen")
# Out:
# By selling pen, you made a profit of 0.00 euros.

# %% [markdown]
# ### Aufgabe 3 / *Exercise 3*
#
# Schreibe eine Funktion, die eine Liste als Eingabe erhält und Zahlen zurückgibt, die größer als ein bestimmter Schwellenwert sind. Der Schwellenwert sollte einen Standardwert von $0.7$ haben.
#
# ---
#
# *Write a function that takes a list as input and returns numbers greater than a given threshold. The threshold should have a default value of $0.7$.*

# %%
l1 = [0.1,2,0.3,4,5,5,0.4,6,7,8,8,9,9,0]

def threshold(lst, threshold = 0.7):

  for x in lst:
    if x > threshold:
      print(x)

threshold(l1)
# Out:
# 2
# 4
# 5
# 5
# 6
# 7
# 8
# 8
# 9
# 9

# %% [markdown]
# # Return statement
# Die return-Anweisung beendet eine Funktion und gibt einen Wert an den Aufruf zurück. Sie kann einen beliebigen Datentyp, mehrere Werte (in einem Tupel verpackt) oder None zurückgeben, wenn kein Wert angegeben wird.
#
# ---
#
# *The return statement ends a function and sends a value back to the caller. It can return any data type, multiple values (packed into a tuple), or `None` if no value is given.*

# %%
def calculate_and_return_profit(item_name, price, cost=10):
    """
    calculates profit of an item.
    input:
        item_name: str
        price: float|int
        cost: float|int. default value 10
    output:
        profit: float|int
    """
    profit = price - cost
    return profit

# %%
item_name = "crayons"
cost = 6
price = 15

profit = calculate_and_return_profit(item_name, price, cost)
print(f'By selling {item_name}, you made a profit of {profit:.2f} euros.')
# Out:
# By selling crayons, you made a profit of 9.00 euros.

# %%
profit = calculateProfit(item_name, price, cost)
print(f"Returned profit: {profit}")
# Out:
# By selling crayons, you made a profit of 9.00 euros.
# Returned profit: None

# %% [markdown]
# ### Aufgabe 4 / *Exercise 4*
# Überprüfe und gib aus, ob der Verkauf einer Leinwand einen Gewinn bringt oder einen Verlust verursacht.
#
# ---
#
# *Check and print whether selling a picture canvas earns a profit or results in loss.*
# ```
# picture_canvas = {
#     "item_name": "photo canvas",
#     "price": 19,
#     "cost": 24
# }
# ```

# %%
picture_canvas = {
    "item_name": "photo canvas",
    "price": 19,
    "cost": 24
}

def profitCheck(item):
  if item["price"] > item["cost"]:
    print('profit')
  elif item["price"] < item["cost"]:
    print('non profit')
  else:
    print('breaks even')




profitCheck(picture_canvas)
# Out:
# non profit

# %% [markdown]
# ### Aufgabe 5 / *Exercise 5*
#
# Sage den Output des folgenden vorher:
# A.
# ```
# def add(a, b):
#     print(a + b)
#
# x = add(4, 5)
# print(x)
# ```
# - Was wird ausgegeben?
# - Warum ist die zweite Aufgabe nicht identisch zur Ersten?
#
# B.
# ```
# def test():
#     return
#     print("Hello")
#
# print(test())
# ```
# Warum wird "Hello" niemals ausgegeben?
#
# C.
# ```
# def add_item(item, lst=[]):
#     lst.append(item)
#     return lst
#
# print(add_item(1))
# print(add_item(2))
# print(add_item(3))
# ```
#
# ---
#
# *Predict the output of the following:*
# A.
# ```
# def add(a, b):
#     print(a + b)
#
# x = add(4, 5)
# print(x)
# ```
# - *What is printed?*
# - *Why is the second output not the same as the first?*
#
# B.
# ```
# def test():
#     return
#     print("Hello")
#
# print(test())
# ```
# *Why is "Hello" never printed?*
#
# C.
# ```
# def add_item(item, lst=[]):
#     lst.append(item)
#     return lst
#
# print(add_item(1))
# print(add_item(2))
# print(add_item(3))
# ```

# %%
def add(a, b):
    print(a + b)

x = add(4, 5)
print(x)
# Out:
# 9
# None

# %%
def add_item(item, lst=[]):
    lst.append(item)
    return lst

print(add_item(1))
print(add_item(2))
print(add_item(3))
# Out:
# [1]
# [1, 2]
# [1, 2, 3]

# %% [markdown]
# ### Aufgabe 6 / *Exercise 6*
# Schreibe eine Funktion, die Celsius nach Fahrenheit konvertiert: $F=C*9/5+32$.
#
# ---
#
# *Write a function that converts Celsius to Fahrenheit: $F=C*9/5+32$.*

# %%
def CelsiusToFahrenheit(celsius):
  return celsius* (9/5) + 32


CelsiusToFahrenheit(100)
# Out:
# 212.0

# %% [markdown]
# # Übergabe durch Referenz und Übergabe durch Wert / *Pass by Reference and Pass by Value*
#
# In Python sind Variablen Referenzen auf Objekte. Wenn wir sie an eine Funktion übergeben, hängt das Verhalten davon ab, ob das Objekt veränderbar (mutable) oder unveränderbar (immutable) ist:
# - Veränderbare Objekte (z. B. Listen, Wörterbücher): Änderungen innerhalb der Funktion wirken sich auf das ursprüngliche Objekt aus.
# - Unveränderbare Objekte (z. B. Integer, Strings, Tupel): Der ursprüngliche Wert bleibt unverändert.
#
# ---
#
# *In Python, variables are references to objects. When we pass them to a function, the behavior depends on whether the object is mutable (like lists, dictionaries) or immutable (like integers, strings, tuples).*
# - *Mutable objects: Changes inside the function affect the original object.*
# - *Immutable objects: The original value remains unchanged.*

# %%
# Function modifies the third element of list
def double_the_item(x):
    x[2] *= 2

lst = [10, 11, 12, 13]
double_the_item(lst)
print(lst)   # list is modified
# Out:
# [10, 11, 24, 13]

# %%
# Function tries to modify an integer
def double_the_item(x):
    x = x * 2
    return x

a = 10
b = double_the_item(a)
print(a)     # integer is not modified
print(b)
# Out:
# 10
# 20

# %% [markdown]
# | Type       | Mutable? | Changes outside function? |
# | ---------- | -------- | ------------------------- |
# | int        | ❌        | No                        |
# | float      | ❌        | No                        |
# | string     | ❌        | No                        |
# | list       | ✅        | Yes                       |
# | dictionary | ✅        | Yes                       |

# %% [markdown]
# ### Aufgabe 7 / Exercise 7
# Sage die Ausgabe vorher.
#
# ---
#
# *Predict the output.*
# ```
# def modify_list(lst):
#     lst = [10, 20, 30]
#
# numbers = [1, 2, 3]
# modify_list(numbers)
# print(numbers)
# ```

# %%
#in the function a new list is created, so no reference and no mutation of 'numbers'
def modify_list(lst):
    lst = [10, 20, 30]

numbers = [1, 2, 3]
modify_list(numbers)
print(numbers)
# Out:
# [1, 2, 3]

# %% [markdown]
# # *args
#
# `*args` ermöglicht einer Funktion, eine beliebige Anzahl von Positionsargumenten zu akzeptieren, die als Tupel gespeichert werden.
#
# ---
#
# *`*args` allows a function to accept any number of positional arguments, which are stored as a tuple.*

# %%
def add_numbers(*args):
    total = 0
    print(type(args))
    for n in args:
        total += n
    return total

print(add_numbers(2, 4, 6))
print(add_numbers(10, 19, 6, 90, 100))
# Out:
# <class 'tuple'>
# 12
# <class 'tuple'>
# 225

# %% [markdown]
# ### **kwargs
#
# `**kwargs` ermöglicht einer Funktion, eine beliebige Anzahl von Schlüsselwortargumenten zu akzeptieren, die als Wörterbuch gespeichert werden.
#
# ---
#
# *`**kwargs` allows a function to accept any number of keyword arguments, which are stored as a dictionary.*

# %%
def print_info(**kwargs):
    for key in kwargs:
        print(key, ":", kwargs[key])

print_info(name="Anna", age=25, city="Berlin")
# Out:
# name : Anna
# age : 25
# city : Berlin

# %%
print_info(name="Laptop", price=1200, brand="Dell")
# Out:
# name : Laptop
# price : 1200
# brand : Dell

# %% [markdown]
# Eine Funktion kann innerhalb ihres Rumpfes eine andere Funktion aufrufen, um Code wiederzuverwenden oder Operationen zu kombinieren.
#
# ---
#
# *A function can call another function inside its body to reuse code or combine operations.*

# %%
# function calling another function
def square(x):
    return x * x

def sum_of_squares(a, b):
    return square(a) + square(b)

print(sum_of_squares(2, 3))

# %% [markdown]
# Außerdem sind Funktionen in Python First-Class-Objekte, was bedeutet, dass sie als Argumente an andere Funktionen übergeben werden können. Manchmal möchten wir verschiedene Operationen auf dieselben Daten anwenden, und durch das Übergeben einer Funktion als Argument kann ein Programm sein Verhalten dynamisch ändern, indem es unterschiedliche Operationen ausführt, ohne die Hauptfunktion neu schreiben zu müssen.
#
# ---
#
# *Moreover, in Python, functions are first-class objects, meaning they can be passed as arguments to other functions. Sometimes you want to apply different operations to the same data and passing a function as an argument allows a program to change its behavior dynamically by applying different operations without rewriting the main function.*

# %%
# passing the function 'square' as argument
def process_numbers(numbers, func):
    result = []
    for n in numbers:
        result.append(func(n))
    return result

numbers = [1,2,3,4]
print(process_numbers(numbers, square))

# %%
def cube(x):
    return x * x * x

print(process_numbers(numbers, cube))

# %% [markdown]
# ### Aufgabe 8 / *Exercise 8*
# Schreibe die folgenden Funktionen:
# * Eine Funktion, die prüft, ob eine Zahl positiv ist
# * Eine Funktion, die prüft, ob eine Zahl durch 9 teilbar ist
# * Eine Funktion, die eine Liste von Zahlen und eine Filterfunktion (eine der obigen) entgegennimmt und die gefilterte Liste zurückgibt.
#
# ---
#
# *Write the following functions:*
# 1. *A function that checks if a number is positive*
# 2. *A function that checks if a number is divisible by 9*
# 3. *A function that takes a list of numbers and a filtering function (either one from the above) and return the filtered list.*

# %%
def isPositive(number):
  if number > 0:
    #print('true')
    return True

  else: return False

isPositive(4)
def checkDiv9(number):
  if number % 9 == 0:
    print('divisable by 9')
    return True

  else: return False

list1 = [4,9,3,2,-7,9,3,18]

def filterList(listx, func):
  result = []
  for x in listx:
    if func(x) != None:
      result.append(func(x))
  return result


filterList(list1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3424/2954133714.py in <cell line: 0>()
#      24
#      25
# ---> 26 filterList(list1)
#
# TypeError: filterList() missing 1 required positional argument: 'func'

# %% [markdown]
# # Rekursive Funktionen / *Recursive Functions*
#
# Eine rekursive Funktion ist eine Funktion, die sich selbst aufruft, um ein Problem zu lösen. Sie wird häufig in mathematischen Problemen oder bei Divide-and-Conquer-Ansätzen verwendet. Es ist immer wichtig, einen Basisfall einzuschließen, um unendliche Rekursion zu vermeiden.
#
# Zwei wichtige Teile existieren immer:
# * Basisfall (Base case) → der Punkt, an dem die Rekursion stoppt
# * Rekursiver Fall (Recursive case) → der Punkt, an dem die Funktion sich selbst aufruft
#
# ---
#
# *A recursive function is a function that calls itself to solve a problem. It is commonly used in mathematical and divide-and-conquer problems. Always include a base case to avoid infinite recursion.*
#
# *Two important parts always exist:*
# - *Base case → when the recursion stops*
# - *Recursive case → when the function calls itself*

# %% [markdown]
# Beispiel: Berechne die Summe der n ersten natürlichen Zahlen:  $sum\_of\_numbers = 1 + 2+ 3 + ... + n$.
#
# ---
#
# *Example: Compute sum of first n natural numbers: $sum\_of\_numbers = 1 + 2+ 3 + ... + n$.*

# %%
def sum_numbers(n):
    print(n)
    # base case: we stop recursion
    if n == 1:
        return 1
    # recursive function call
    return n + sum_numbers(n-1)

# %%
print(sum_numbers(4))
# Out:
# 4
# 3
# 2
# 1
# 10

# %% [markdown]
# ### Aufgabe 9 / *Exercise 9*
#
# Die Fakultät von $n$ wird berechnet als $n! = 1 \times 2 \times 3 \times ... \times (n-1) \times n$.
# Schreibe eine Funktion, um $n!$ rekursiv zu berechnen.
#
# ---
#
# *Factorial of $n$ is calculated as $n! = 1 \times 2 \times 3 \times ... \times (n-1) \times n$.
# Write a function to calculate $n!$ recursively.*

# %%
def fact(n):
  print(n)
  if n == 1:
    return 1
  return n * fact(n-1)

fact(5)
# Out:
# 5
# 4
# 3
# 2
# 1
# 120

# %% [markdown]
# # Eingebaute Funktionen / *Built-in Function*
#
# Eine eingebaute Funktion (built-in function) ist eine vorgefertigte Funktion, die wir verwenden können, ohne sie selbst zu definieren. Diese Funktionen führen häufige Aufgaben aus, wie Berechnungen, Datenmanipulation oder Typumwandlungen. Beispiele: `print()` zum Ausgeben von Informationen, `len()` zum Ermitteln der Länge einer Sammlung, `sum()` zum Addieren von Zahlen und `type()` zum Prüfen des Typs einer Variablen.
#
# ---
#
# *A built-in function is the ready-to-use functions that we can use without defining it. These functions perform common tasks such as calculations, data manipulation, and type conversion. Examples: `print()` for displaying output, `len()` for finding the length of a collection, `sum()` for adding numbers, and `type()` for checking the type of a variable.*
#
# | Function      | Purpose                                       | Example                      |
# | ------------- | --------------------------------------------- | ---------------------------- |
# | `print()`     | Displays output to the screen                 | `print("Hello")`             |
# | `len()`       | Returns the number of items in an object      | `len([1,2,3]) → 3`           |
# | `type()`      | Shows the data type of a variable             | `type(5) → int`              |
# | `int()`       | Converts a value to an integer                | `int("10") → 10`             |
# | `float()`     | Converts a value to a float                   | `float("3.5") → 3.5`         |
# | `str()`       | Converts a value to a string                  | `str(10) → "10"`             |
# | `sum()`       | Returns the sum of numbers in an iterable     | `sum([1,2,3]) → 6`           |
# | `max()`       | Returns the largest value                     | `max(3,7,5) → 7`             |
# | `min()`       | Returns the smallest value                    | `min(3,7,5) → 3`             |
# | `abs()`       | Returns the absolute value                    | `abs(-4) → 4`                |
# | `round()`     | Rounds a number to a given precision          | `round(3.1416,2) → 3.14`     |
# | `range()`     | Generates a sequence of numbers               | `range(1,5)`                 |
# | `sorted()`    | Returns a sorted list                         | `sorted([3,1,2]) → [1,2,3]`  |
# | `input()`     | Reads user input from the keyboard            | `name = input("Enter name")` |
# | `enumerate()` | Returns index and value pairs from a sequence | `enumerate(['a','b'])`       |

# %% [markdown]
# # Lambda Function
#
# Lambda-Funktionen sind kleine anonyme Funktionen, das heißt, sie haben keinen definierten Namen. Sie sind kurze, kurzlebige Funktionen, die verwendet werden, um einfache Logik an eine andere Funktion zu übergeben.
# - Sie enthalten nur einen Ausdruck.
# - Das Ergebnis dieses Ausdrucks wird automatisch zurückgegeben (kein return-Schlüsselwort erforderlich).
#
# ---
#
# *Lambda functions are small anonymous functions, meaning they do not have a defined name. These are small, short-lived functions used to pass simple logic to another function.*
# - *Contain only one expression.*
# - *Result of that expression is returned automatically (no return keyword needed).*
#
# Syntax:
# ```
# lambda arguments: expression
# ```
#
# Examples:
#
# ```
# square = lambda x: x * x
# print(square(5))
#
# # Output: 25
# ```
#
# ```
# add = lambda a, b: a + b
# print(add(3, 4))
#
# # Output: 7
# ```

# %% [markdown]
# # Finale Aufgabe / *Final Exercise: Mini Netflix Analytics*
#
# Wir haben Daten über user und die Filme, die sie angesehen haben, sowie Bewertungen auf einer Skala von 1 bis 5.
# ```
# ratings = {
#     "Alice": {"Inception": 5, "Titanic": 3, "Avatar": 4},
#     "Bob": {"Inception": 4, "Titanic": 2, "Avatar": 5},
#     "Charlie": {"Inception": 5, "Titanic": 4, "Avatar": 3},
#     "Diana": {"Inception": 4, "Titanic": 3, "Avatar": 4}
# }
# ```
#
# Lass uns die Daten für unsere kleine Streaming-Plattform analysieren.
# 1. Erstelle für jede der folgenden Aufgaben eine Funktion. Die Funktion sollte ratings und den Namen eines Films als Eingabeargumente erhalten.
#     * Zähle, wie viele Zuschauer einen Film gesehen haben.
#     * Berechne die durchschnittliche Bewertung eines Films.
# 2. Erstelle eine Funktion, die den höchstbewerteten Film eines Benutzers findet.
# 3. Erstelle eine Funktion, die den insgesamt höchstbewerteten Film empfiehlt.
#
# ---
#
# *You have data about users and the movies they watched with ratings out of 5.*
# ```
# ratings = {
#     "Alice": {"Inception": 5, "Titanic": 3, "Avatar": 4},
#     "Bob": {"Inception": 4, "Titanic": 2, "Avatar": 5},
#     "Charlie": {"Inception": 5, "Titanic": 4, "Avatar": 3},
#     "Diana": {"Inception": 4, "Titanic": 3, "Avatar": 4}
# }
# ```
# *Lets analyze the data for our small streaming platform.*
# 1. *Create a function for each of the following tasks. The function should take `ratings` and a movie name as input arguments.*
#     - *Count how many viewer have seen a movie.*
#     - *Calculate the average rating of a movie.*
# 2. *Create a function that finds a user's highest rated movie.*
# 3. *Create a function that recommend the highest rated movie overall.*

# %%
ratings = {
    "Alice": {"Inception": 5, "Titanic": 3, "Avatar": 4},
    "Bob": {"Inception": 4, "Titanic": 2, "Avatar": 5},
    "Charlie": {"Inception": 5, "Titanic": 4, "Avatar": 3},
    "Diana": {"Inception": 4, "Titanic": 3, "Avatar": 4}
}

def count_viewers(ratings, movie):
    count = 0
    for user in ratings:
        if movie in ratings[user]:
            count += 1
    return count

def average_rating(ratings, movie):
  count = 0
  total = 0
  for user in ratings:
    if movie in ratings[user]:
          total += ratings[user][movie]
          count += 1
    return total / count if count > 0 else 0

print(count_viewers(ratings, "Inception"))
print(average_rating(ratings, "Inception"))
print(count_viewers(ratings, "Titanic"))
print(average_rating(ratings, "Titanic"))
print(count_viewers(ratings, "Avatar"))
print(average_rating(ratings, "Avatar"))

def user_best(ratings, user):
  if user not in ratings or not ratings[user]:
      return None

  max_rating = 0
  user_best_movie = None

  for movie, rating in ratings[user].items():
    if rating > max_rating:
          max_rating = rating
          user_best_movie = movie
          print(user_best_movie)
  print(f"best movie, according to {user}, is {user_best_movie}.")
  return user_best_movie

print(user_best(ratings, "Bob"))


def movie_best(ratings):
    movies = set()
    # get all distinct movies from the dict 'ratings'
    for user in ratings:
        movies.update(ratings[user].keys())

    best_movie = None
    best_avg = -1

    for movie in movies:
        avg = average_rating(ratings, movie)
        if avg > best_avg:
            best_avg = avg
            best_movie = movie

    return best_movie

movie_best(ratings)
# Out:
# 4
# 5.0
# 4
# 3.0
# 4
# 4.0
# Inception
# Avatar
# best movie, according to Bob, is Avatar.
# Avatar
# 'Inception'
