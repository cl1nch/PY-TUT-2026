# %% [markdown]
# <a href="https://colab.research.google.com/github/cl1nch/PY-TUT-2026/blob/main/numpy_advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OWL-ML/IBFW-PY-2026-Tutorial/blob/main/numpy_advanced.ipynb)
#
# *(Tip: Ctrl/Cmd + click to open in a new tab)*

# %%
import numpy as np

# %% [markdown]
# #### NumPy ufuncs oder universelle Funktionen / *NumPy ufuncs or universal functions*
#
# NumPy ufuncs (universelle Funktionen) sind schnelle, vektorisierte Funktionen, die elementweise Operationen auf NumPy-Arrays ausführen. Sie sind hoch optimiert und unterstützen Funktionen wie Broadcasting und automatische Typbehandlung. NumPy enthält viele ufuncs für Arithmetik, Trigonometrie, Statistik usw., und sie führen Operationen sehr schnell aus, da sie in optimiertem C-Code implementiert sind.
#
# ##### Warum sollten wir ufuncs verwenden?
# - Schnelle vektorisierte Operationen: Ufuncs wenden Berechnungen auf ganze Arrays gleichzeitig an, was sie wesentlich schneller als Python-Schleifen macht.
# - Automatisches Broadcasting und Typbehandlung: Sie passen Array-Formen automatisch an und führen intern Datentypkonvertierungen durch, wodurch Fehler reduziert werden.
# - Saubererer und effizienterer Code: Sie vereinfachen komplexe numerische Aufgaben zu kurzem, lesbarem Code, der gut auf großen Datensätzen skaliert.
#
# ---
#
# *NumPy ufuncs (universal functions) are fast, vectorized functions that perform element-wise operations on NumPy arrays. They are highly optimized and support features like broadcasting and automatic type handling. NumPy includes many ufuncs for arithmetic, trigonometry, statistics, etc, and they execute operations very fast because they are implemented in optimized C code.*
#
# ##### *Why use ufuncs?*
# - *Fast vectorized operations: Ufuncs apply calculations to entire arrays at once, making them much faster than Python loops.*
# - *Automatic broadcasting and type handling: They adjust array shapes automatically and handle datatype conversion internally, reducing errors.*
# - *Cleaner and more efficient code: They simplify complex numerical tasks into short, readable code that scales well on large datasets.*
#
# ##### Beispiele für universelle Funktionen in Python / *Examples Universal Functions in Numpy*
#
# ```
# a = np.array([1, 2, 3])
# b = np.array([4, 5, 6])
# ```
#
# | Funktion        | Typ   | Beschreibung                | Beispielcode        | Ausgabe               |
# | --------------- | ----- | --------------------------- | ------------------- | --------------------- |
# | `np.add()`      | ufunc | Elementweise Addition       | `np.add(a, b)`      | `[5 7 9]`             |
# | `np.subtract()` | ufunc | Elementweise Subtraktion    | `np.subtract(a, b)` | `[-3 -3 -3]`          |
# | `np.multiply()` | ufunc | Elementweise Multiplikation | `np.multiply(a, b)` | `[4 10 18]`           |
# | `np.divide()`   | ufunc | Elementweise Division       | `np.divide(a, b)`   | `[0.25 0.4 0.5]`      |
# | `np.power()`    | ufunc | Elemente potenzieren        | `np.power(a, b)`    | `[1^4, 2^5, 3^6]`     |
# | `np.mod()`      | ufunc | Elementweiser Restwert      | `np.mod(a, b)`      | `[1 2 3]`             |
# | `np.maximum()`  | ufunc | Elementweises Maximum       | `np.maximum(a, b)`  | `[4 5 6]`             |
# | `np.minimum()`  | ufunc | Elementweises Minimum       | `np.minimum(a, b)`  | `[1 2 3]`             |
# | `np.greater()`  | ufunc | Elementweise Vergleich      | `np.greater(a, b)`  | `[False False False]` |
# | `np.equal()`    | ufunc | Elementweise Gleichheit     | `np.equal(a, b)`    | `[False False False]` |
#
#
#
# ---
#
# | Function        | Type  | Description                 | Example Code        | Output                |
# | --------------- | ----- | --------------------------- | ------------------- | --------------------- |
# | `np.add()`      | ufunc | Element-wise addition       | `np.add(a, b)`      | `[5 7 9]`             |
# | `np.subtract()` | ufunc | Element-wise subtraction    | `np.subtract(a, b)` | `[-3 -3 -3]`          |
# | `np.multiply()` | ufunc | Element-wise multiplication | `np.multiply(a, b)` | `[4 10 18]`           |
# | `np.divide()`   | ufunc | Element-wise division       | `np.divide(a, b)`   | `[0.25 0.4 0.5]`      |
# | `np.power()`    | ufunc | Raise elements to powers    | `np.power(a, b)`    | `[1^4, 2^5, 3^6]`     |
# | `np.mod()`      | ufunc | Element-wise remainder      | `np.mod(a, b)`      | `[1 2 3]`             |
# | `np.maximum()`  | ufunc | Element-wise max            | `np.maximum(a, b)`  | `[4 5 6]`             |
# | `np.minimum()`  | ufunc | Element-wise min            | `np.minimum(a, b)`  | `[1 2 3]`             |
# | `np.greater()`  | ufunc | Element-wise comparison     | `np.greater(a, b)`  | `[False False False]` |
# | `np.equal()`    | ufunc | Element-wise equality       | `np.equal(a, b)`    | `[False False False]` |

# %% [markdown]
# Überprüfe, ob eine Funktion ein ufunc ist:
#
# ---
#
# *Check if a function is ufunc:*

# %%
print(type(np.add))
# Out:
# <class 'numpy.ufunc'>

# %%
print(type(np.reshape))
# Out:
# <class 'numpy._ArrayFunctionDispatcher'>

# %% [markdown]
# # In-Place-Operationen mit NumPy-ufuncs / *In-Place Operations using NumPy ufuncs*
#
#
# In NumPy verändern In-Place-Operationen ein bestehendes Array, ohne eine neue Kopie zu erstellen, wodurch sie speichereffizienter und schneller sind.
#
# Viele ufuncs unterstützen In-Place-Aktualisierungen über Parameter wie `out`.
#
# ---
#
# *In NumPy, in-place operations modify an existing array without creating a new copy, making them more memory-efficient and faster.*
#
# *Many ufuncs support in-place updates using parameters like `out`.*

# %%
# Create a NumPy array
arr = np.array([2, 4, 6])
print(np.multiply(arr, 2))
print(arr)
# multiply each element by 2 and store in arr
np.multiply(arr, 2, out=arr)
print(arr)

# %%
# Create a NumPy array
array_x = np.array([1, 2, 3, 4, 5])

# Create another array to add
array_y = np.array([10, 20, 30, 40, 50])

# Perform in-place addition using np.add with the out parameter
np.add(array_x, array_y, out=array_x)

# Print the resulting array
print("Resulting Array after In-Place Addition:")
print(array_x)

# %% [markdown]
# # Erstellen von eigenen ufunc / *How To Create Your Own ufunc*
#
# Um eine eigene ufunc zu erstellen, müssen wir zunächst eine Funktion definieren, wie bei normalen Python-Funktionen.
# Anschließend fügen wir sie mit der Methode frompyfunc() zur NumPy-ufunc-Bibliothek hinzu.
#
# Die Methode frompyfunc() nimmt die folgenden Argumente:
# * `function` – der Name der Funktion
# * `inputs` – die Anzahl der Eingabeargumente (Arrays)
# * `outputs` – die Anzahl der Ausgabearrays
#
# ---
#
# To create your own ufunc, you have to define a function, like you do with normal functions in Python, then you add it to your NumPy ufunc library with the `frompyfunc()` method.
#
# The `frompyfunc()` method takes the following arguments:
# - `function` - the name of the function.
# - `inputs` - the number of input arguments (arrays).
# - `outputs` - the number of output arrays.

# %%
def custom_add(x, y):
  return x+y

custom_add = np.frompyfunc(custom_add, 2, 1)

print(type(custom_add))

# %%
array_x = np.array([1, 2, 3, 4, 5])
array_y = np.array([10, 20, 30, 40, 50])

array_sum = custom_add(array_x, array_y)
print(array_sum)

# %% [markdown]
# # Aufgaben / *Exercises*

# %% [markdown]
# ## Aufgabe 1 / *Exercise 1*
#
# Schreibe ein NumPy-Programm, das die np.sqrt-ufunc verwendet, um die Quadratwurzel jedes Elements in einem 2D-NumPy-Array zu berechnen.
#
# ---
#
# *Write a NumPy program that uses the `np.sqrt` ufunc to compute the square root of each element in a 2D NumPy array.*

# %%
arr1 = np.array([[1, 4, 9], [16, 25, 36]])

sqrt_arr = np.sqrt(arr1)
print(sqrt_arr)
# Out:
# [[1. 2. 3.]
#  [4. 5. 6.]]

# %% [markdown]
# ## Aufgabe 2 / *Exercise 2*
#
# Schreibe ein NumPy-Programm, das ein 2D-NumPy-Array und ein 1D-Array erstellt. Verwende die np.add-ufunc, um das 1D-Array zu jeder Zeile des 2D-Arrays zu addieren.
#
# ---
#
# *Write a NumPy program that creates a 2D NumPy array and a 1D array. Use the np.add ufunc to add the 1D array to each row of the 2D array.*

# %%
# add your solution here

# %% [markdown]
# ## Aufgabe 3 / *Exercise 3*
#
# Schreibe ein NumPy-Programm, das eine benutzerdefinierte ufunc erstellt, die für jedes Element in einem NumPy-Array $x^2 + 2x + 1$ berechnet.
#
# ---
#
# *Write a NumPy program that creates a custom ufunc that computes $x^2 + 2x + 1$ for each element in a NumPy array.*

# %%
# add your solution here

# %% [markdown]
# ## Aufgabe 4 / *Exercise 4*
#
# Schreibe ein NumPy-Programm, das eine benutzerdefinierte ufunc erstellt, die auf komplexe Zahlen in einem NumPy-Array angewendet wird.
#
# ---
#
# *Write a NumPy program that creates a custom ufunc to operate on complex numbers in a NumPy array.*

# %%
# add your solution here

# %% [markdown]
# ## Aufgabe 5 / *Exercise 5*
#
# Verwende das out-Argument der ufuncs, um $a = (a + b)^2$ zu berechnen, gegeben:
#
# ```
# a = np.array([1,2,3])
# b = np.array([4,5,6])
# ```
#
# ---
#
# *Using ufunc out calculate $a = (a + b)^2$, provided the above arrays.*

# %%
# add your solution here

# %% [markdown]
# # Matrix / Linear Algebra Operations
#
# ```
# A = np.array([[1,2], [3,4]])
#
# B = np.array([[5,6], [7,8]])
# ```
#
# | Funktion      | Beschreibung                     | Beispielcode      | Ausgabe             |
# | ------------- | -------------------------------- | ----------------- | ------------------- |
# | `np.dot()`    | Matrixmultiplikation             | `np.dot(A, B)`    | `[[19 22],[43 50]]` |
# | `np.matmul()` | Matrixmultiplikation (bevorzugt) | `np.matmul(A, B)` | gleich wie oben     |
# | `@` Operator  | Matrixmultiplikation             | `A @ B`           | gleich wie oben     |
#
#
# ---
#
#
# | Function      | Description                       | Example Code      | Output              |
# | ------------- | --------------------------------- | ----------------- | ------------------- |
# | `np.dot()`    | Matrix multiplication             | `np.dot(A, B)`    | `[[19 22],[43 50]]` |
# | `np.matmul()` | Matrix multiplication (preferred) | `np.matmul(A, B)` | same as above       |
# | `@` operator  | Matrix multiplication             | `A @ B`           | same as above       |

# %% [markdown]
# ### NumPy Linear Algebra Module
#
# NumPy stellt ein spezielles Modul namens `np.linalg` bereit, um lineare Algebra-Operationen durchzuführen, wie z. B. das Lösen von Gleichungssystemen, das Berechnen von Determinanten, Inversen und Vektornormen. Es wird häufig in Data Science, Machine Learning und wissenschaftlichem Rechnen verwendet.
#
# ```
# A = np.array([[1, 2],[3, 4]])
# b = np.array([5, 6])
# ```
#
# | Funktion                  | Beschreibung                        | Beispielcode               | Ausgabe                      |
# | ------------------------- | ----------------------------------- | -------------------------- | ---------------------------- |
# | `np.linalg.det()`         | Determinante einer Matrix           | `np.linalg.det(A)`         | `-2.0`                       |
# | `np.linalg.inv()`         | Inverse einer Matrix                | `np.linalg.inv(A)`         | `[[-2. , 1. ], [1.5, -0.5]]` |
# | `np.linalg.solve()`       | Lösen eines linearen Systems Ax = b | `np.linalg.solve(A, b)`    | `[ -4. , 4.5 ]`              |
# | `np.linalg.eig()`         | Eigenwerte & Eigenvektoren          | `np.linalg.eig(A)`         | Werte + Vektoren             |
# | `np.linalg.norm()`        | Vektor-/Matrixnorm                  | `np.linalg.norm([3,4])`    | `5.0`                        |
# | `np.linalg.matrix_rank()` | Rang einer Matrix                   | `np.linalg.matrix_rank(A)` | `2`                          |
# | `np.linalg.trace()`       | Summe der Diagonalelemente          | `np.trace(A)`              | `5`                          |
# | `np.linalg.svd()`         | Singulärwertzerlegung               | `np.linalg.svd(A)`         | U, S, V Matrizen             |
# | `np.linalg.pinv()`        | Pseudo-Inverse                      | `np.linalg.pinv(A)`        | Matrix                       |
# | `np.linalg.cond()`        | Konditionszahl                      | `np.linalg.cond(A)`        | Zahlenwert                   |
#
#
# ---
#
# NumPy provides a dedicated module called `np.linalg` for performing linear algebra operations such as solving equations, computing determinants, inverses, and vector norms. It is widely used in data science, machine learning, and scientific computing.
#
# ```
# A = np.array([[1, 2],[3, 4]])
# b = np.array([5, 6])
# ```
#
# | Function                  | Description                  | Example Code               | Output                       |
# | ------------------------- | ---------------------------- | -------------------------- | ---------------------------- |
# | `np.linalg.det()`         | Determinant of matrix        | `np.linalg.det(A)`         | `-2.0`                       |
# | `np.linalg.inv()`         | Inverse of matrix            | `np.linalg.inv(A)`         | `[[-2. , 1. ], [1.5, -0.5]]` |
# | `np.linalg.solve()`       | Solve linear system Ax = b   | `np.linalg.solve(A, b)`    | `[ -4. , 4.5 ]`              |
# | `np.linalg.eig()`         | Eigenvalues & eigenvectors   | `np.linalg.eig(A)`         | values + vectors             |
# | `np.linalg.norm()`        | Vector/matrix norm           | `np.linalg.norm([3,4])`    | `5.0`                        |
# | `np.linalg.matrix_rank()` | Rank of matrix               | `np.linalg.matrix_rank(A)` | `2`                          |
# | `np.linalg.trace()`       | Sum of diagonal elements     | `np.trace(A)`              | `5`                          |
# | `np.linalg.svd()`         | Singular Value Decomposition | `np.linalg.svd(A)`         | U, S, V matrices             |
# | `np.linalg.pinv()`        | Pseudo-inverse               | `np.linalg.pinv(A)`        | matrix                       |
# | `np.linalg.cond()`        | Condition number             | `np.linalg.cond(A)`        | numeric value                |

# %% [markdown]
# # Aufgabe / *Exercise*
#
# Gegeben `A = np.array([[1, 2], [3, 4]])`, schreibe Code, um die folgenden Aufgaben auszuführen:
# 1. Eine Matrix ist invertierbar, wenn ihre Determinante ungleich null ist. Überprüfe, ob die gegebene Matrix invertierbar ist, und falls ja, berechne die Inverse.
# 2. Multipliziere `A` und `A_inv`.
#
# ---
#
# *Given `A = np.array([[1, 2], [3, 4]])`, write code to perform the following tasks:*
# 1. *A matrix is invertible if its determinant is a non-zero value. Check if the given matrix is invertible and if it is, then calculate the inverse.*
# 2. *Multiply `A` and `A_inv`.*

# %%
# add your solution here
